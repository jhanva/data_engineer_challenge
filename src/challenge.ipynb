# %% [markdown]
# # Data Engineer Challenge

# %% [markdown]
# Autor: Johan Vargas

# %% [markdown]
# El objetivo de este notebook es proporcionar soluciones al desafío de Ingeniero de Datos presentado. En este desafío, se abordarán una serie de problemas relacionados con el procesamiento de datos utilizando Python y diferentes enfoques para optimizar tanto el tiempo de ejecución como la memoria en uso. Como participante, mi tarea será resolver estos desafíos aplicando mis habilidades y conocimientos en el manejo eficiente de grandes conjuntos de datos, así como implementando soluciones creativas y modulares.

# %%
# %load_ext autoreload
# %autoreload 2
# %cd ../
# Out:
# D:\Johan\repositorios\data_engineer_challenge

# %% [markdown]
# En este notebook, el código está organizado en módulos para mejorar la estructura y la legibilidad del proyecto. Se utiliza una estructura de carpetas que incluye un directorio llamado "metadata", donde se define una clase "Path" que contiene las rutas necesarias para el proyecto. Además, hay un módulo llamado "utils" que contiene dos scripts: "readers" para leer los archivos JSON y "filters" con funciones útiles para filtrar datos.
#
# La utilización de módulos permite separar distintas funcionalidades de manera lógica y coherente, lo que facilita la gestión del código y su reutilización en diferentes partes del proyecto. La clase "Path" proporciona un acceso centralizado a las rutas del proyecto, lo que hace que sea más fácil modificarlas en un solo lugar si es necesario. Los scripts en el módulo "utils" contienen funciones genéricas que pueden ser útiles en varias partes del proyecto, como leer archivos JSON y aplicar filtros a los datos.
#
# Esta organización modular contribuye a mantener un código más ordenado, modular y fácil de mantener, lo que es fundamental en proyectos de análisis de datos de gran escala como este desafío de Ingeniero de Datos.

# %% [markdown]
# ## Librerias

# %%
# External libraries
import cProfile

# Own libraries
from src.metadata.path import Path

from src.q1_memory import q1_memory
from src.q1_time import q1_time
from src.q2_memory import q2_memory
from src.q2_time import q2_time
from src.q3_memory import q3_memory
from src.q3_time import q3_time

# %% [markdown]
# 1. Las top 10 fechas donde hay más tweets. Mencionar el usuario (username) que más publicaciones tiene por cada uno de esos días. Debe incluir las siguientes funciones:
# ```python
# def q1_time(file_path: str) -> List[Tuple[datetime.date, str]]:
# ```
# ```python
# def q1_memory(file_path: str) -> List[Tuple[datetime.date, str]]:
# ```
# ```python
# Returns:
# [(datetime.date(1999, 11, 15), "LATAM321"), (datetime.date(1999, 7, 15), "LATAM_CHI"), ...]
# ```

# %% [markdown]
# Esta solución optimiza el uso de memoria al procesar los datos de manera eficiente y almacenar solo la información necesaria para calcular el usuario más activo para cada fecha. En lugar de crear estructuras de datos adicionales para almacenar conteos de usuarios, se utiliza un diccionario date_user para mapear cada fecha a un diccionario de usuarios y sus respectivos conteos. Esto permite realizar los cálculos necesarios con una cantidad mínima de memoria, ya que no se necesita almacenar información redundante. Además, la función profile se utiliza para realizar la profilización de la memoria y optimizar aún más el uso de recursos durante la ejecución del script.

# %%
result = q1_memory(Path.tweets)
# Out:
# Filename: D:\Johan\repositorios\data_engineer_challenge\src\q1_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     12    117.5 MiB    117.5 MiB           1   @profile
#     13                                         def q1_memory(file_path: str) -> List[Tuple[datetime.date, str]]:
#     14                                             """Lee un archivo JSON y devuelve una lista de tuplas que contiene la
#     15                                              fecha y el usuario más activo para cada día.
#     16
#     17                                             Args:
#     18                                                 file_path (str): Ruta del archivo JSON.
#     19
#     20                                             Returns:
#     21                                                 List[Tuple[datetime.date, str]]: Lista de tuplas donde cada tupla
#     22                                                  contiene la fecha (como objeto datetime.date) y el usuario más activo
#     23                                                  para ese día.
#     24
#     25                                             """
#     26    139.9 MiB     22.4 MiB           1       data = read_json_file(file_path, transformation='date_list')
#     27
#     28    139.9 MiB      0.0 MiB           1       user_counts = {}
#     29    139.9 MiB      0.0 MiB           1       date_user = {}
#     30
#     31    139.9 MiB      0.0 MiB      117408       for date, user in data:
#     32    139.9 MiB      0.0 MiB      117407           if date not in date_user:
#     33    139.9 MiB      0.0 MiB          13               date_user[date] = {}
#     34    139.9 MiB      0.0 MiB      117407           date_user[date][user] = date_user[date].get(user, 0) + 1
#     35
#     36    139.9 MiB      0.0 MiB          14       for date, users in date_user.items():
#     37    139.9 MiB      0.0 MiB          13           user_counts[date] = max(users, key=users.get)
#     38
#     39    139.9 MiB      0.0 MiB           2       sorted_user_counts = sorted(
#     40    139.9 MiB      0.0 MiB          27           user_counts.items(), key=lambda x: x[1], reverse=True
#     41                                             )
#     42
#     43    139.9 MiB      0.0 MiB           1       return sorted_user_counts

# %%
result
# Out:
# [(datetime.date(2021, 2, 14), 'rebelpacifist'),
#  (datetime.date(2021, 2, 24), 'preetysaini321'),
#  (datetime.date(2021, 2, 22), 'preetysaini321'),
#  (datetime.date(2021, 2, 18), 'neetuanjle_nitu'),
#  (datetime.date(2021, 2, 16), 'jot__b'),
#  (datetime.date(2021, 2, 15), 'jot__b'),
#  (datetime.date(2021, 2, 23), 'Surrypuria'),
#  (datetime.date(2021, 2, 21), 'Surrypuria'),
#  (datetime.date(2021, 2, 12), 'RanbirS00614606'),
#  (datetime.date(2021, 2, 17), 'RaaJVinderkaur'),
#  (datetime.date(2021, 2, 19), 'Preetm91'),
#  (datetime.date(2021, 2, 20), 'MangalJ23056160'),
#  (datetime.date(2021, 2, 13), 'MaanDee08215437')]

# %% [markdown]
# Esta solución optimiza el tiempo de ejecución al aprovechar la eficiencia y las capacidades de la biblioteca pandas para el procesamiento de datos. En lugar de utilizar bucles manuales para realizar cálculos y manipulaciones de datos, se utiliza el método groupby de pandas para agrupar los datos por fecha y calcular el usuario más activo para cada día de manera eficiente. Además, se aprovecha la función agg para aplicar múltiples funciones de agregación en una sola operación, lo que reduce el tiempo de procesamiento. Esta solución es especialmente eficaz para conjuntos de datos grandes, ya que pandas está optimizado para el manejo de datos tabulares y puede realizar operaciones de manera vectorizada, lo que resulta en una mayor velocidad de ejecución.

# %%
cProfile.run('q1_time(Path.tweets)')
# Out:
#          729265 function calls (728465 primitive calls) in 5.271 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(all)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amax)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(append)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(argsort)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(array_equal)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_2d)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(bincount)
#        29    0.000    0.000    0.061    0.002 <__array_function__ internals>:177(concatenate)
#        82    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copyto)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(diff)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(insert)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(isclose)
#         1    0.000    0.000    0.003    0.003 <__array_function__ internals>:177(lexsort)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(moveaxis)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(ndim)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(nonzero)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(ravel)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(repeat)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(result_type)
#         3    0.000    0.000    0.061    0.020 <__array_function__ internals>:177(vstack)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:1022(_find_and_load)
#        30    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:357(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:391(cached)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:404(parent)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:412(has_location)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:48(_new_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:492(_init_module_attrs)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:564(module_from_spec)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:664(_load_unlocked)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:746(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:826(find_spec)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:893(__enter__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:897(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:921(_find_spec)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:987(_find_and_load_unlocked)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1040(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1065(get_filename)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1070(get_data)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1089(path_stats)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:119(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:134(<genexpr>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1356(_path_importer_cache)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1399(_get_spec)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1431(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1531(_get_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1536(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:159(_path_isfile)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:172(_path_isabs)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:380(cache_from_source)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:510(_get_cached)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:542(_check_name_wrapper)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:585(_classify_pyc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:618(_validate_timestamp_pyc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:67(_relax_case)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:670(_compile_bytecode)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:721(spec_from_file_location)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:84(_unpack_uint32)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:874(create_module)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap_external>:877(exec_module)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:950(get_code)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
#         1    0.319    0.319    5.271    5.271 <string>:1(<module>)
#        72    0.000    0.000    0.000    0.000 __init__.py:33(using_copy_on_write)
#         1    0.000    0.000    0.000    0.000 __init__.py:89(find_spec)
#         7    0.000    0.000    0.000    0.000 _asarray.py:109(<setcomp>)
#         7    0.000    0.000    0.000    0.000 _asarray.py:22(require)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:262(__subclasshook__)
#        10    0.000    0.000    0.000    0.000 _collections_abc.py:283(__subclasshook__)
#        45    0.000    0.000    0.000    0.000 _collections_abc.py:315(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:362(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:381(__subclasshook__)
#        58    0.000    0.000    0.000    0.000 _collections_abc.py:409(__subclasshook__)
#        12    0.000    0.000    0.000    0.000 _collections_abc.py:78(_check_methods)
#        11    0.000    0.000    0.000    0.000 _decorators.py:340(doc)
#        11    0.000    0.000    0.001    0.000 _decorators.py:360(decorator)
#        11    0.000    0.000    0.000    0.000 _decorators.py:376(<listcomp>)
#        11    0.000    0.000    0.001    0.000 _decorators.py:384(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _decorators.py:434(__init__)
#         1    0.000    0.000    0.000    0.000 _decorators.py:440(__call__)
#         1    0.000    0.000    0.000    0.000 _decorators.py:474(__init__)
#         1    0.000    0.000    0.000    0.000 _decorators.py:481(__call__)
#         2    0.000    0.000    0.000    0.000 _dtype.py:178(_datetime_metadata_str)
#        25    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#        25    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#        25    0.000    0.000    0.000    0.000 _dtype.py:344(_name_get)
#         2    0.000    0.000    0.000    0.000 _exceptions.py:11(rewrite_exception)
#         1    0.000    0.000    0.000    0.000 _internal.py:918(npy_ctypes_check)
#         3    0.000    0.000    0.000    0.000 _methods.py:38(_amax)
#         3    0.000    0.000    0.000    0.000 _methods.py:42(_amin)
#         9    0.000    0.000    0.000    0.000 _methods.py:54(_any)
#         6    0.000    0.000    0.000    0.000 _methods.py:60(_all)
#         1    0.000    0.000    0.000    0.000 _mixins.py:110(_box_func)
#         5    0.000    0.000    0.002    0.000 _mixins.py:155(take)
#         2    0.000    0.000    0.000    0.000 _mixins.py:189(_values_for_argsort)
#         9    0.000    0.000    0.000    0.000 _mixins.py:266(__getitem__)
#         2    0.000    0.000    0.001    0.000 _mixins.py:83(method)
#         2    0.000    0.000    0.000    0.000 _parser.py:1006(_find_hms_idx)
#         2    0.000    0.000    0.000    0.000 _parser.py:1056(_could_be_tzname)
#         2    0.000    0.000    0.000    0.000 _parser.py:1061(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _parser.py:1099(_parse_min_sec)
#         1    0.000    0.000    0.000    0.000 _parser.py:1133(_parsems)
#         3    0.000    0.000    0.000    0.000 _parser.py:1141(_to_decimal)
#         1    0.000    0.000    0.000    0.000 _parser.py:1177(_build_tzaware)
#         1    0.000    0.000    0.000    0.000 _parser.py:1217(_build_naive)
#         1    0.000    0.000    0.000    0.000 _parser.py:1270(parse)
#         1    0.000    0.000    0.000    0.000 _parser.py:186(__iter__)
#        16    0.000    0.000    0.000    0.000 _parser.py:189(__next__)
#         1    0.000    0.000    0.000    0.000 _parser.py:199(split)
#        16    0.000    0.000    0.000    0.000 _parser.py:203(isword)
#        31    0.000    0.000    0.000    0.000 _parser.py:208(isnum)
#         6    0.000    0.000    0.000    0.000 _parser.py:213(isspace)
#         1    0.000    0.000    0.000    0.000 _parser.py:221(__init__)
#         1    0.000    0.000    0.000    0.000 _parser.py:233(__len__)
#        13    0.000    0.000    0.000    0.000 _parser.py:234(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _parser.py:319(jump)
#         2    0.000    0.000    0.000    0.000 _parser.py:322(weekday)
#         3    0.000    0.000    0.000    0.000 _parser.py:329(month)
#         3    0.000    0.000    0.000    0.000 _parser.py:336(hms)
#         2    0.000    0.000    0.000    0.000 _parser.py:342(ampm)
#         1    0.000    0.000    0.000    0.000 _parser.py:360(convertyear)
#         1    0.000    0.000    0.000    0.000 _parser.py:380(validate)
#         1    0.000    0.000    0.000    0.000 _parser.py:395(__init__)
#         1    0.000    0.000    0.000    0.000 _parser.py:402(has_year)
#         3    0.000    0.000    0.000    0.000 _parser.py:428(append)
#         1    0.000    0.000    0.000    0.000 _parser.py:474(resolve_ymd)
#         1    0.000    0.000    0.000    0.000 _parser.py:482(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 _parser.py:572(parse)
#         1    0.000    0.000    0.000    0.000 _parser.py:62(__init__)
#         1    0.000    0.000    0.000    0.000 _parser.py:666(_parse)
#        16    0.000    0.000    0.000    0.000 _parser.py:77(get_token)
#         2    0.000    0.000    0.000    0.000 _parser.py:875(_parse_numeric_token)
#         1    0.000    0.000    0.000    0.000 _ranges.py:20(generate_regular_range)
#         1    0.000    0.000    0.000    0.000 _strptime.py:238(pattern)
#         2    0.000    0.000    0.000    0.000 _strptime.py:26(_getlang)
#         1    0.000    0.000    0.001    0.001 _strptime.py:261(compile)
#        10    0.000    0.000    0.000    0.000 _ufunc_config.py:131(geterr)
#        10    0.000    0.000    0.000    0.000 _ufunc_config.py:32(seterr)
#         5    0.000    0.000    0.000    0.000 _ufunc_config.py:425(__init__)
#         5    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__enter__)
#         5    0.000    0.000    0.000    0.000 _ufunc_config.py:434(__exit__)
#        28    0.000    0.000    0.000    0.000 _validators.py:224(validate_bool_kwarg)
#        14    0.000    0.000    0.000    0.000 _validators.py:349(validate_ascending)
#         1    0.000    0.000    0.000    0.000 _validators.py:393(validate_inclusive)
#        18    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#    141/24    0.000    0.000    0.001    0.000 abc.py:121(__subclasscheck__)
#        14    0.000    0.000    0.000    0.000 algorithms.py:105(_ensure_data)
#         9    0.000    0.000    0.003    0.000 algorithms.py:1164(take)
#        14    0.000    0.000    0.000    0.000 algorithms.py:183(_reconstruct_data)
#        14    0.000    0.000    0.000    0.000 algorithms.py:216(_ensure_arraylike)
#         1    0.000    0.000    0.001    0.001 algorithms.py:250(_get_hashtable_algo)
#         1    0.000    0.000    0.001    0.001 algorithms.py:268(_check_object_for_strings)
#         1    0.000    0.000    0.003    0.003 algorithms.py:295(unique)
#         1    0.000    0.000    0.003    0.003 algorithms.py:415(unique_with_mask)
#        13    0.000    0.000    0.041    0.003 algorithms.py:799(value_counts)
#        13    0.032    0.002    0.032    0.002 algorithms.py:907(value_counts_arraylike)
#         1    0.000    0.000    0.000    0.000 api.py:112(_get_combined_index)
#         5    0.000    0.000    0.000    0.000 api.py:367(default_index)
#         1    0.000    0.000    0.000    0.000 api.py:68(get_objs_combined_axis)
#         1    0.000    0.000    0.000    0.000 api.py:94(<listcomp>)
#         1    0.000    0.000    0.000    0.000 api.py:98(_get_distinct_objs)
#         2    0.002    0.001    0.057    0.029 apply.py:1010(apply)
#         3    0.000    0.000    0.000    0.000 apply.py:103(__init__)
#         2    0.000    0.000    0.055    0.028 apply.py:1061(apply_standard)
#         1    0.000    0.000    0.000    0.000 apply.py:1093(__init__)
#         1    0.000    0.000    0.000    0.000 apply.py:1145(reconstruct_func)
#         1    0.000    0.000    0.000    0.000 apply.py:1425(maybe_mangle_lambdas)
#         1    0.000    0.000    0.066    0.066 apply.py:145(agg)
#         1    0.000    0.000    0.066    0.066 apply.py:374(agg_dict_like)
#         1    0.000    0.000    0.065    0.065 apply.py:420(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 apply.py:428(<listcomp>)
#         1    0.000    0.000    0.000    0.000 apply.py:433(<listcomp>)
#         1    0.000    0.000    0.000    0.000 apply.py:444(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 apply.py:509(normalize_dictlike_arg)
#         3    0.000    0.000    0.000    0.000 apply.py:526(<genexpr>)
#         3    0.000    0.000    0.000    0.000 apply.py:543(<genexpr>)
#         2    0.000    0.000    0.000    0.000 apply.py:991(__init__)
#         1    0.000    0.000    0.003    0.003 astype.py:162(astype_array)
#         1    0.000    0.000    0.003    0.003 astype.py:196(astype_array_safe)
#         6    0.000    0.000    0.002    0.000 base.py:1070(take)
#         6    0.000    0.000    0.000    0.000 base.py:1101(_maybe_disallow_fill)
#         1    0.000    0.000    0.000    0.000 base.py:1175(copy)
#        22    0.000    0.000    0.000    0.000 base.py:1582(name)
#        13    0.000    0.000    0.000    0.000 base.py:1589(name)
#         1    0.000    0.000    0.000    0.000 base.py:1600(_validate_names)
#         1    0.000    0.000    0.000    0.000 base.py:162(array)
#         5    0.000    0.000    0.000    0.000 base.py:1668(_get_names)
#         3    0.000    0.000    0.000    0.000 base.py:1671(_set_names)
#         2    0.000    0.000    0.000    0.000 base.py:1716(set_names)
#         1    0.000    0.000    0.000    0.000 base.py:1823(rename)
#         1    0.000    0.000    0.007    0.007 base.py:191(grouped_reduce)
#         4    0.001    0.000    0.001    0.000 base.py:2121(is_monotonic_increasing)
#         1    0.000    0.000    0.000    0.000 base.py:214(_obj_with_exclusions)
#         2    0.000    0.000    0.000    0.000 base.py:2205(is_unique)
#         1    0.000    0.000    0.000    0.000 base.py:2636(inferred_type)
#         2    0.000    0.000    0.000    0.000 base.py:2660(_is_multi)
#         4    0.000    0.000    0.000    0.000 base.py:2678(_na_value)
#         7    0.000    0.000    0.000    0.000 base.py:286(is_dtype)
#         2    0.000    0.000    0.000    0.000 base.py:309(shape)
#        35    0.000    0.000    0.000    0.000 base.py:326(ndim)
#         3    0.000    0.000    0.000    0.000 base.py:359(size)
#        14    0.000    0.000    0.000    0.000 base.py:3624(get_loc)
#         3    0.000    0.000    0.000    0.000 base.py:450(_engine_type)
#         5    0.000    0.000    0.000    0.000 base.py:46(__len__)
#        25    0.000    0.000    0.043    0.002 base.py:469(__new__)
#         3    0.000    0.000    0.000    0.000 base.py:4926(array)
#        37    0.000    0.000    0.000    0.000 base.py:4936(_values)
#         4    0.000    0.000    0.000    0.000 base.py:494(find)
#         3    0.000    0.000    0.000    0.000 base.py:4962(_get_engine_target)
#         1    0.000    0.000    0.000    0.000 base.py:5070(_validate_fill_value)
#        19    0.000    0.000    0.000    0.000 base.py:5108(__contains__)
#        50    0.001    0.000    0.002    0.000 base.py:5158(__getitem__)
#        13    0.000    0.000    0.000    0.000 base.py:5204(_getitem_slice)
#         6    0.000    0.000    0.000    0.000 base.py:530(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:5313(equals)
#         9    0.000    0.000    0.000    0.000 base.py:54(shape)
#         2    0.000    0.000    0.000    0.000 base.py:5400(identical)
#         6    0.000    0.000    0.000    0.000 base.py:5413(<genexpr>)
#        27    0.000    0.000    0.000    0.000 base.py:56(<genexpr>)
#         3    0.000    0.000    0.000    0.000 base.py:563(empty)
#        25    0.000    0.000    0.000    0.000 base.py:565(_ensure_array)
#        38    0.000    0.000    0.000    0.000 base.py:58(_validate_set_axis)
#        25    0.000    0.000    0.000    0.000 base.py:583(_dtype_to_subclass)
#         1    0.000    0.000    0.000    0.000 base.py:6137(map)
#        14    0.000    0.000    0.000    0.000 base.py:6351(_maybe_cast_indexer)
#        63    0.000    0.000    0.000    0.000 base.py:640(_simple_new)
#         2    0.000    0.000    0.010    0.005 base.py:653(argsort)
#         1    0.000    0.000    0.000    0.000 base.py:6611(insert)
#         3    0.000    0.000    0.000    0.000 base.py:665(_with_infer)
#        15    0.000    0.000    0.000    0.000 base.py:683(_constructor)
#         1    0.000    0.000    0.001    0.001 base.py:6967(min)
#         1    0.000    0.000    0.000    0.000 base.py:6992(max)
#        75    0.000    0.000    0.000    0.000 base.py:7069(ensure_index)
#        73    0.000    0.000    0.000    0.000 base.py:7164(maybe_extract_name)
#         3    0.000    0.000    0.000    0.000 base.py:760(_view)
#         8    0.000    0.000    0.000    0.000 base.py:767(__iter__)
#         1    0.000    0.000    0.000    0.000 base.py:769(_rename)
#         3    0.000    0.000    0.000    0.000 base.py:778(is_)
#        68    0.000    0.000    0.000    0.000 base.py:809(_reset_identity)
#         6    0.000    0.000    0.000    0.000 base.py:820(_engine)
#         1    0.000    0.000    0.000    0.000 base.py:825(_map_values)
#       152    0.000    0.000    0.000    0.000 base.py:875(__len__)
#        13    0.000    0.000    0.042    0.003 base.py:928(value_counts)
#        18    0.000    0.000    0.000    0.000 base.py:931(dtype)
#         1    0.000    0.000    0.000    0.000 base.py:983(astype)
#         2    0.000    0.000    0.000    0.000 blocks.py:1503(delete)
#        11    0.000    0.000    0.000    0.000 blocks.py:164(_consolidate_key)
#        10    0.000    0.000    0.000    0.000 blocks.py:192(fill_value)
#        19    0.000    0.000    0.000    0.000 blocks.py:205(mgr_locs)
#         1    0.000    0.000    0.000    0.000 blocks.py:213(make_block)
#        12    0.000    0.000    0.000    0.000 blocks.py:230(make_block_same_class)
#        42    0.000    0.000    0.000    0.000 blocks.py:2303(maybe_coerce_values)
#        48    0.000    0.000    0.000    0.000 blocks.py:2332(get_block_type)
#         7    0.000    0.000    0.000    0.000 blocks.py:2370(new_block_2d)
#        34    0.000    0.000    0.001    0.000 blocks.py:2383(new_block)
#        34    0.000    0.000    0.000    0.000 blocks.py:2399(check_ndim)
#        11    0.000    0.000    0.000    0.000 blocks.py:2463(extend_blocks)
#         4    0.000    0.000    0.000    0.000 blocks.py:2479(ensure_block_shape)
#         4    0.000    0.000    0.000    0.000 blocks.py:258(__len__)
#        32    0.000    0.000    0.000    0.000 blocks.py:479(dtype)
#         1    0.000    0.000    0.003    0.003 blocks.py:483(astype)
#         5    0.000    0.000    0.000    0.000 blocks.py:534(copy)
#         2    0.000    0.000    0.000    0.000 blocks.py:888(shape)
#        10    0.000    0.000    0.000    0.000 blocks.py:892(iget)
#        13    0.000    0.000    0.000    0.000 blocks.py:901(_slice)
#        12    0.000    0.000    0.089    0.007 blocks.py:926(take_nd)
#        52    0.000    0.000    0.052    0.001 cast.py:1145(maybe_infer_to_datetimelike)
#         4    0.000    0.000    0.000    0.000 cast.py:121(maybe_convert_platform)
#         1    0.000    0.000    0.000    0.000 cast.py:1460(construct_1d_arraylike_from_scalar)
#         4    0.000    0.000    0.000    0.000 cast.py:1521(construct_1d_object_array_from_listlike)
#         1    0.000    0.000    0.000    0.000 cast.py:1698(np_can_hold_element)
#         2    0.000    0.000    0.000    0.000 cast.py:538(ensure_dtype_can_hold_na)
#        15    0.000    0.000    0.000    0.000 cast.py:564(maybe_promote)
#         3    0.000    0.000    0.000    0.000 cast.py:610(_maybe_promote_cached)
#         3    0.000    0.000    0.000    0.000 cast.py:618(_maybe_promote)
#        44    0.000    0.000    0.000    0.000 common.py:1077(needs_i8_conversion)
#         1    0.000    0.000    0.000    0.000 common.py:1127(is_numeric_dtype)
#        12    0.000    0.000    0.000    0.000 common.py:1209(is_float_dtype)
#        11    0.000    0.000    0.000    0.000 common.py:1240(<lambda>)
#        22    0.000    0.000    0.000    0.000 common.py:1244(is_bool_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:1305(is_1d_only_ea_obj)
#        64    0.000    0.000    0.000    0.000 common.py:1322(is_1d_only_ea_dtype)
#        39    0.000    0.000    0.000    0.000 common.py:1335(is_extension_array_dtype)
#        50    0.000    0.000    0.000    0.000 common.py:1389(is_ea_or_datetimelike_dtype)
#        30    0.000    0.000    0.000    0.000 common.py:142(classes)
#        18    0.000    0.000    0.000    0.000 common.py:1435(_is_dtype)
#        30    0.000    0.000    0.000    0.000 common.py:144(<lambda>)
#        78    0.000    0.000    0.000    0.000 common.py:1459(get_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:147(classes_and_not_datetimelike)
#        40    0.000    0.000    0.000    0.000 common.py:1494(_is_dtype_type)
#        36    0.000    0.000    0.000    0.000 common.py:150(cast_scalar_indexer)
#        10    0.000    0.000    0.000    0.000 common.py:152(<lambda>)
#        18    0.000    0.000    0.000    0.000 common.py:158(is_object_dtype)
#        74    0.000    0.000    0.000    0.000 common.py:1631(validate_all_hashable)
#       148    0.000    0.000    0.000    0.000 common.py:1650(<genexpr>)
#        21    0.000    0.000    0.000    0.000 common.py:1656(pandas_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:207(count_not_none)
#         5    0.000    0.000    0.000    0.000 common.py:211(<genexpr>)
#        17    0.000    0.000    0.000    0.000 common.py:229(asarray_tuplesafe)
#         3    0.000    0.000    0.000    0.000 common.py:275(is_datetime64_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:296(maybe_iterable_to_list)
#         2    0.000    0.000    0.000    0.000 common.py:309(is_datetime64tz_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:351(is_timedelta64_dtype)
#        13    0.000    0.000    0.000    0.000 common.py:367(apply_if_callable)
#         8    0.000    0.000    0.000    0.000 common.py:386(is_period_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:460(is_categorical_dtype)
#        16    0.000    0.000    0.000    0.000 common.py:498(is_string_or_object_np_dtype)
#        19    0.000    0.000    0.000    0.000 common.py:551(is_dtype_equal)
#         4    0.000    0.000    0.000    0.000 common.py:551(temp_setattr)
#        51    0.000    0.000    0.000    0.000 common.py:571(require_length_match)
#         1    0.000    0.000    0.000    0.000 common.py:622(get_cython_func)
#         1    0.000    0.000    0.000    0.000 common.py:629(is_builtin_func)
#         9    0.000    0.000    0.000    0.000 common.py:653(is_integer_dtype)
#         7    0.000    0.000    0.000    0.000 common.py:705(<lambda>)
#        13    0.000    0.000    0.000    0.000 common.py:95(is_bool_indexer)
#         1    0.000    0.000    0.001    0.001 concat.py:149(concat)
#         1    0.000    0.000    0.000    0.000 concat.py:393(__init__)
#         1    0.000    0.000    0.000    0.000 concat.py:424(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:480(<listcomp>)
#         1    0.000    0.000    0.001    0.001 concat.py:565(get_result)
#         1    0.000    0.000    0.000    0.000 concat.py:625(_get_result_dim)
#         1    0.000    0.000    0.000    0.000 concat.py:631(_get_new_axes)
#         1    0.000    0.000    0.000    0.000 concat.py:633(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:638(_get_comb_axis)
#         1    0.000    0.000    0.000    0.000 concat.py:648(_get_concat_axis)
#        34    0.000    0.000    0.000    0.000 config.py:116(_get_single_key)
#        34    0.000    0.000    0.000    0.000 config.py:134(_get_option)
#        34    0.000    0.000    0.000    0.000 config.py:260(__call__)
#        34    0.000    0.000    0.000    0.000 config.py:578(_select_options)
#        34    0.000    0.000    0.000    0.000 config.py:596(_get_root)
#        68    0.000    0.000    0.000    0.000 config.py:610(_get_deprecated_option)
#        34    0.000    0.000    0.000    0.000 config.py:637(_translate_key)
#        34    0.000    0.000    0.000    0.000 config.py:649(_warn_if_deprecated)
#         1    0.000    0.000    0.167    0.167 construction.py:1001(convert_object_array)
#        21    0.000    0.000    0.167    0.008 construction.py:1023(convert)
#         1    0.000    0.000    0.167    0.167 construction.py:1067(<listcomp>)
#         2    0.000    0.000    0.000    0.000 construction.py:197(mgr_to_mgr)
#       112    0.000    0.000    0.001    0.000 construction.py:396(extract_array)
#         1    0.000    0.000    0.001    0.001 construction.py:411(dict_to_mgr)
#        65    0.000    0.000    0.000    0.000 construction.py:458(ensure_wrapped_if_datetimelike)
#         1    0.000    0.000    0.000    0.000 construction.py:469(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:470(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:476(<listcomp>)
#         1    0.000    0.000    0.412    0.412 construction.py:484(nested_data_to_arrays)
#        78    0.001    0.000    0.048    0.001 construction.py:494(sanitize_array)
#         1    0.000    0.000    0.000    0.000 construction.py:510(treat_as_nested)
#         2    0.000    0.000    0.006    0.003 construction.py:574(_homogenize)
#         4    0.000    0.000    0.000    0.000 construction.py:636(_sanitize_non_ordered)
#        77    0.000    0.000    0.000    0.000 construction.py:644(_sanitize_ndim)
#        70    0.000    0.000    0.000    0.000 construction.py:683(_sanitize_str_dtypes)
#        77    0.000    0.000    0.000    0.000 construction.py:703(_maybe_repeat)
#         1    0.000    0.000    0.000    0.000 construction.py:714(_try_cast)
#         1    0.002    0.002    0.412    0.412 construction.py:775(to_arrays)
#         1    0.000    0.000    0.243    0.243 construction.py:886(_list_of_dict_to_arrays)
#    117408    0.071    0.000    0.080    0.000 construction.py:910(<genexpr>)
#         2    0.000    0.000    0.000    0.000 construction.py:911(<genexpr>)
#         1    0.019    0.019    0.019    0.019 construction.py:917(<listcomp>)
#         1    0.000    0.000    0.167    0.167 construction.py:923(_finalize_columns_and_data)
#         1    0.000    0.000    0.000    0.000 construction.py:945(_validate_or_indexify_columns)
#         2    0.030    0.015    0.232    0.116 construction.py:97(arrays_to_mgr)
#         3    0.000    0.000    0.000    0.000 contextlib.py:102(__init__)
#         3    0.000    0.000    0.000    0.000 contextlib.py:130(__enter__)
#         3    0.000    0.000    0.000    0.000 contextlib.py:139(__exit__)
#         3    0.000    0.000    0.000    0.000 contextlib.py:279(helper)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:1210(is_dataclass)
#         6    0.000    0.000    0.000    0.000 datetimelike.py:102(asi8)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:123(hasnans)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:127(equals)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:1796(__init__)
#        13    0.000    0.000    0.000    0.000 datetimelike.py:1872(freq)
#         5    0.000    0.000    0.000    0.000 datetimelike.py:1941(_creso)
#         4    0.000    0.000    0.000    0.000 datetimelike.py:1945(unit)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2116(ensure_arraylike_for_datetimelike)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2160(validate_periods)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2187(validate_inferred_freq)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2224(maybe_infer_freq)
#         4    0.000    0.000    0.000    0.000 datetimelike.py:2252(dtype_to_unit)
#        13    0.000    0.000    0.000    0.000 datetimelike.py:307(asi8)
#         1    0.017    0.017    0.226    0.226 datetimelike.py:342(__array__)
#         8    0.000    0.000    0.000    0.000 datetimelike.py:359(__getitem__)
#         5    0.000    0.000    0.000    0.000 datetimelike.py:380(_get_getitem_freq)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:421(unit)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:437(astype)
#         3    0.000    0.000    0.000    0.000 datetimelike.py:543(copy)
#         3    0.000    0.000    0.000    0.000 datetimelike.py:589(_validate_scalar)
#         3    0.000    0.000    0.000    0.000 datetimelike.py:689(_get_engine_target)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:752(map)
#         2    0.000    0.000    0.001    0.001 datetimelike.py:767(take)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:823(isna)
#         3    0.000    0.000    0.000    0.000 datetimelike.py:826(_isnan)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:833(_hasna)
#         4    0.000    0.000    0.000    0.000 datetimelike.py:93(freq)
#         1    0.000    0.000    0.004    0.004 datetimes.py:132(_guess_datetime_format_for_array)
#         1    0.000    0.000    0.000    0.000 datetimes.py:1332(date)
#         1    0.000    0.000    0.000    0.000 datetimes.py:155(should_cache)
#         6    0.000    0.000    0.000    0.000 datetimes.py:196(_scalar_type)
#         1    0.000    0.000    0.034    0.034 datetimes.py:1986(_sequence_to_dt64ns)
#         1    0.000    0.000    0.032    0.032 datetimes.py:2137(objects_to_datetime64ns)
#         1    0.000    0.000    0.001    0.001 datetimes.py:215(_maybe_cache)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2209(maybe_convert_dtype)
#         3    0.000    0.000    0.000    0.000 datetimes.py:2293(_validate_dt64_dtype)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2347(_validate_tz_from_dtype)
#         1    0.000    0.000    0.000    0.000 datetimes.py:2400(_infer_tz_from_endpoints)
#         1    0.000    0.000    0.000    0.000 datetimes.py:2443(_maybe_normalize_endpoints)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2456(_maybe_localize_point)
#         3    0.000    0.000    0.000    0.000 datetimes.py:252(_engine_type)
#         1    0.000    0.000    0.000    0.000 datetimes.py:260(_validate_dtype)
#         3    0.000    0.000    0.000    0.000 datetimes.py:268(_simple_new)
#         1    0.000    0.000    0.034    0.034 datetimes.py:293(_from_sequence_not_strict)
#         1    0.000    0.000    0.034    0.034 datetimes.py:306(__new__)
#         1    0.004    0.004    0.273    0.273 datetimes.py:317(_return_parsed_timezone_results)
#         1    0.000    0.000    0.436    0.436 datetimes.py:352(_convert_listlike_datetimes)
#         1    0.000    0.000    0.000    0.000 datetimes.py:374(_generate_range)
#         1    0.003    0.003    0.432    0.432 datetimes.py:473(_array_strptime_with_fallback)
#         2    0.000    0.000    0.000    0.000 datetimes.py:485(<genexpr>)
#         3    0.000    0.000    0.000    0.000 datetimes.py:507(_unbox_scalar)
#         3    0.000    0.000    0.000    0.000 datetimes.py:519(_check_compatible_with)
#         3    0.000    0.000    0.000    0.000 datetimes.py:527(_box_func)
#        85    0.000    0.000    0.000    0.000 datetimes.py:533(dtype)
#        23    0.000    0.000    0.000    0.000 datetimes.py:558(tz)
#         1    0.000    0.000    0.226    0.226 datetimes.py:600(__array__)
#    117408    0.009    0.000    0.067    0.000 datetimes.py:607(__iter__)
#         1    0.000    0.000    0.000    0.000 datetimes.py:636(astype)
#         1    0.000    0.000    0.437    0.437 datetimes.py:687(to_datetime)
#         1    0.000    0.000    0.000    0.000 datetimes.py:758(date_range)
#         1    0.000    0.000    0.000    0.000 datetimes.py:787(_local_timestamps)
#         1    0.000    0.000    0.000    0.000 datetimes.py:875(tz_localize)
#         3    0.000    0.000    0.000    0.000 datetimes.py:96(tz_to_dtype)
#         1    0.000    0.000    0.000    0.000 dtypes.py:1324(__init__)
#         4    0.000    0.000    0.000    0.000 dtypes.py:677(na_value)
#         3    0.000    0.000    0.000    0.000 dtypes.py:686(__init__)
#         3    0.000    0.000    0.000    0.000 dtypes.py:718(_creso)
#        22    0.000    0.000    0.000    0.000 dtypes.py:725(unit)
#        38    0.000    0.000    0.000    0.000 dtypes.py:732(tz)
#         2    0.000    0.000    0.000    0.000 dtypes.py:788(__str__)
#         1    0.000    0.000    0.000    0.000 dtypes.py:791(name)
#        15    0.000    0.000    0.000    0.000 dtypes.py:801(__eq__)
#         3    0.000    0.000    0.000    0.000 dtypes.py:974(is_dtype)
#         1    0.000    0.000    0.000    0.000 dtypes.py:98(__repr__)
#         8    0.000    0.000    0.000    0.000 enum.py:359(__call__)
#         8    0.000    0.000    0.000    0.000 enum.py:678(__new__)
#         3    0.000    0.000    0.000    0.000 enum.py:801(value)
#         4    0.000    0.000    0.000    0.000 enum.py:986(__and__)
#         1    0.000    0.000    0.000    0.000 extension.py:156(map)
#        19    0.000    0.000    0.000    0.000 extension.py:70(fget)
#        68    0.000    0.000    0.000    0.000 flags.py:49(__init__)
#        48    0.000    0.000    0.000    0.000 flags.py:53(allows_duplicate_labels)
#        47    0.000    0.000    0.000    0.000 flags.py:85(allows_duplicate_labels)
#         3    0.000    0.000    0.002    0.001 frame.py:11607(_reindex_for_setitem)
#         4    0.000    0.000    0.000    0.000 frame.py:1489(__len__)
#        10    0.000    0.000    0.001    0.000 frame.py:3639(_ixs)
#        10    0.000    0.000    0.001    0.000 frame.py:3713(__getitem__)
#         3    0.000    0.000    0.003    0.001 frame.py:3931(__setitem__)
#         3    0.000    0.000    0.001    0.000 frame.py:4111(_iset_item_mgr)
#         3    0.000    0.000    0.001    0.000 frame.py:4118(_set_item_mgr)
#         3    0.000    0.000    0.003    0.001 frame.py:4143(_set_item)
#         4    0.000    0.000    0.000    0.000 frame.py:4213(_ensure_valid_index)
#        10    0.000    0.000    0.000    0.000 frame.py:4236(_box_col_values)
#         5    0.000    0.000    0.000    0.000 frame.py:4250(_clear_item_cache)
#        10    0.000    0.000    0.001    0.000 frame.py:4253(_get_item_cache)
#         1    0.000    0.000    0.000    0.000 frame.py:4721(insert)
#         4    0.000    0.000    0.003    0.001 frame.py:4857(_sanitize_column)
#         4    0.000    0.000    0.000    0.000 frame.py:632(_constructor)
#         6    0.000    0.000    0.645    0.108 frame.py:641(__init__)
#         1    0.000    0.000    0.001    0.001 frame.py:6719(sort_values)
#         1    0.000    0.000    0.258    0.258 frame.py:8140(groupby)
#         3    0.000    0.000    0.000    0.000 frame.py:893(axes)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1008(_argsort_dispatcher)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1012(argsort)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1751(_ravel_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1755(ravel)
#        16    0.000    0.000    0.000    0.000 fromnumeric.py:1862(_nonzero_dispatcher)
#        16    0.000    0.000    0.000    0.000 fromnumeric.py:1866(nonzero)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:2401(_all_dispatcher)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:2406(all)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2672(_amax_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2677(amax)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3117(_ndim_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3121(ndim)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:432(_repeat_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:436(repeat)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 frozen.py:73(__getitem__)
#         2    0.000    0.000    0.000    0.000 function.py:151(validate_argsort_with_ascending)
#         2    0.000    0.000    0.000    0.000 function.py:374(validate_minmax_axis)
#         9    0.000    0.000    0.000    0.000 function.py:60(__call__)
#         1    0.000    0.000    0.000    0.000 function_base.py:1315(_diff_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:1319(diff)
#         1    0.000    0.000    0.000    0.000 function_base.py:5191(_insert_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:5195(insert)
#         2    0.000    0.000    0.000    0.000 function_base.py:5385(_append_dispatcher)
#         2    0.000    0.000    0.000    0.000 function_base.py:5389(append)
#         1    0.000    0.000    0.067    0.067 generic.py:1258(aggregate)
#         1    0.000    0.000    0.000    0.000 generic.py:140(_wrap_agged_manager)
#         1    0.000    0.000    0.000    0.000 generic.py:143(_get_data_to_aggregate)
#         1    0.000    0.000    0.000    0.000 generic.py:1638(_is_label_reference)
#         2    0.000    0.000    0.000    0.000 generic.py:1660(<genexpr>)
#         2    0.000    0.000    0.000    0.000 generic.py:1665(<genexpr>)
#         1    0.000    0.000    0.000    0.000 generic.py:1693(_check_label_or_level_ambiguity)
#         1    0.000    0.000    0.000    0.000 generic.py:1714(<genexpr>)
#         1    0.000    0.000    0.000    0.000 generic.py:1737(_get_label_or_level_values)
#         1    0.000    0.000    0.000    0.000 generic.py:1770(<listcomp>)
#         2    0.000    0.000    0.000    0.000 generic.py:1773(_gotitem)
#         1    0.000    0.000    0.000    0.000 generic.py:1924(__contains__)
#         2    0.000    0.000    0.065    0.033 generic.py:218(aggregate)
#        68    0.000    0.000    0.000    0.000 generic.py:265(__init__)
#         1    0.000    0.000    0.053    0.053 generic.py:283(_python_agg_general)
#        13    0.000    0.000    0.042    0.003 generic.py:285(<lambda>)
#        48    0.000    0.000    0.000    0.000 generic.py:338(attrs)
#        95    0.000    0.000    0.000    0.000 generic.py:359(flags)
#       696    0.000    0.000    0.000    0.000 generic.py:37(_check)
#         2    0.000    0.000    0.091    0.045 generic.py:3832(take)
#         2    0.000    0.000    0.091    0.045 generic.py:3911(_take)
#         1    0.000    0.000    0.000    0.000 generic.py:3954(xs)
#         3    0.000    0.000    0.000    0.000 generic.py:4176(_check_setitem_copy)
#       696    0.000    0.000    0.001    0.000 generic.py:42(_instancecheck)
#         1    0.000    0.000    0.000    0.000 generic.py:453(_validate_dtype)
#        35    0.000    0.000    0.000    0.000 generic.py:509(_get_axis_number)
#         2    0.000    0.000    0.000    0.000 generic.py:5106(reindex)
#         6    0.000    0.000    0.000    0.000 generic.py:523(_get_axis)
#         4    0.000    0.000    0.000    0.000 generic.py:529(_get_block_manager_axis)
#         4    0.000    0.000    0.000    0.000 generic.py:5348(<genexpr>)
#        47    0.000    0.000    0.001    0.000 generic.py:5931(__finalize__)
#         2    0.000    0.000    0.000    0.000 generic.py:5963(<genexpr>)
#         3    0.000    0.000    0.000    0.000 generic.py:5968(<genexpr>)
#        38    0.000    0.000    0.000    0.000 generic.py:5975(__getattr__)
#         6    0.000    0.000    0.000    0.000 generic.py:599(_info_axis)
#        62    0.000    0.000    0.001    0.000 generic.py:5991(__setattr__)
#         1    0.000    0.000    0.083    0.083 generic.py:6046(_protect_consolidate)
#         1    0.000    0.000    0.083    0.083 generic.py:6069(_consolidate)
#         1    0.000    0.000    0.083    0.083 generic.py:6079(<lambda>)
#         1    0.000    0.000    0.003    0.003 generic.py:6161(astype)
#         4    0.000    0.000    0.000    0.000 generic.py:623(ndim)
#         2    0.000    0.000    0.000    0.000 generic.py:6342(copy)
#        38    0.000    0.000    0.000    0.000 generic.py:723(_set_axis)
#         1    0.000    0.000    0.000    0.000 groupby.py:1091(_insert_inaxis_grouper)
#         1    0.000    0.000    0.000    0.000 groupby.py:1101(<listcomp>)
#         2    0.000    0.000    0.000    0.000 groupby.py:1115(_maybe_transpose_result)
#         2    0.000    0.000    0.000    0.000 groupby.py:1126(_wrap_aggregated_output)
#         1    0.000    0.000    0.011    0.011 groupby.py:1728(count)
#         1    0.000    0.000    0.007    0.007 groupby.py:1746(hfunc)
#         3    0.000    0.000    0.000    0.000 groupby.py:4008(_reindex_output)
#         1    0.000    0.000    0.000    0.000 groupby.py:650(ngroups)
#         2    0.000    0.000    0.000    0.000 groupby.py:721(_selected_obj)
#         3    0.000    0.000    0.258    0.086 groupby.py:897(__init__)
#         4    0.000    0.000    0.000    0.000 groupby.py:946(__getattr__)
#         1    0.000    0.000    0.000    0.000 grouper.py:1022(_is_label_like)
#         1    0.000    0.000    0.000    0.000 grouper.py:1026(_convert_grouper)
#         1    0.000    0.000    0.002    0.002 grouper.py:249(__new__)
#         1    0.000    0.000    0.000    0.000 grouper.py:256(__init__)
#         2    0.000    0.000    0.103    0.051 grouper.py:311(_set_grouper)
#         1    0.000    0.000    0.258    0.258 grouper.py:508(__init__)
#         1    0.000    0.000    0.000    0.000 grouper.py:619(_passed_categorical)
#         1    0.000    0.000    0.000    0.000 grouper.py:623(name)
#         1    0.000    0.000    0.000    0.000 grouper.py:641(_ilevel)
#         1    0.000    0.000    0.004    0.004 grouper.py:669(codes)
#         1    0.000    0.000    0.000    0.000 grouper.py:673(group_arraylike)
#         1    0.000    0.000    0.000    0.000 grouper.py:688(result_index)
#         1    0.000    0.000    0.000    0.000 grouper.py:700(group_index)
#         1    0.000    0.000    0.004    0.004 grouper.py:722(_codes_and_uniques)
#         1    0.000    0.000    0.258    0.258 grouper.py:790(get_grouper)
#         2    0.000    0.000    0.000    0.000 grouper.py:891(<genexpr>)
#         2    0.000    0.000    0.000    0.000 grouper.py:892(<genexpr>)
#         2    0.000    0.000    0.000    0.000 grouper.py:893(<genexpr>)
#         1    0.000    0.000    0.000    0.000 grouper.py:927(is_in_axis)
#         1    0.000    0.000    0.000    0.000 grouper.py:943(is_in_obj)
#         1    0.000    0.000    0.000    0.000 index_tricks.py:322(__getitem__)
#        10    0.000    0.000    0.000    0.000 indexing.py:2602(check_dict_or_set_indexers)
#        23    0.000    0.000    0.000    0.000 inference.py:189(is_array_like)
#        17    0.000    0.000    0.000    0.000 inference.py:267(is_dict_like)
#        53    0.000    0.000    0.000    0.000 inference.py:294(<genexpr>)
#         1    0.000    0.000    0.000    0.000 inference.py:300(is_named_tuple)
#       162    0.000    0.000    0.000    0.000 inference.py:328(is_hashable)
#         1    0.000    0.000    0.000    0.000 inference.py:367(is_sequence)
#         1    0.000    0.000    0.000    0.000 inference.py:398(is_dataclass)
#         1    0.000    0.000    0.000    0.000 inspect.py:191(isclass)
#         2    0.000    0.000    0.000    0.000 locale.py:396(normalize)
#         2    0.000    0.000    0.000    0.000 locale.py:479(_parse_localename)
#         2    0.000    0.000    0.000    0.000 locale.py:587(getlocale)
#         3    0.000    0.000    0.000    0.000 managers.py:1017(from_blocks)
#        10    0.000    0.000    0.000    0.000 managers.py:1084(iget)
#         3    0.000    0.000    0.001    0.000 managers.py:1138(iset)
#         2    0.000    0.000    0.000    0.000 managers.py:1195(value_getitem)
#         2    0.000    0.000    0.000    0.000 managers.py:1281(_iset_split_block)
#         1    0.000    0.000    0.000    0.000 managers.py:1328(_iset_single)
#         1    0.000    0.000    0.000    0.000 managers.py:1387(insert)
#         4    0.000    0.000    0.000    0.000 managers.py:1426(<genexpr>)
#         1    0.000    0.000    0.000    0.000 managers.py:1436(_insert_update_mgr_locs)
#         1    0.000    0.000    0.000    0.000 managers.py:1446(_insert_update_blklocs_and_blknos)
#        19    0.000    0.000    0.000    0.000 managers.py:167(blknos)
#         4    0.000    0.000    0.000    0.000 managers.py:1805(is_consolidated)
#         4    0.000    0.000    0.000    0.000 managers.py:1813(_consolidate_check)
#         4    0.000    0.000    0.000    0.000 managers.py:1819(<listcomp>)
#         3    0.000    0.000    0.174    0.058 managers.py:1823(_consolidate_inplace)
#        16    0.000    0.000    0.000    0.000 managers.py:183(blklocs)
#        19    0.000    0.000    0.000    0.000 managers.py:1838(ndim)
# ...
#        20    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#        69    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFCC069C920}
#        18    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#    141/24    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         3    0.000    0.000    0.000    0.000 {built-in method _from_value_and_reso}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#         6    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         6    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         2    0.000    0.000    0.000    0.000 {built-in method _locale.setlocale}
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         3    0.000    0.000    0.000    0.000 {built-in method _simple_new}
#         4    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#        17    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_iscased}
#         3    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_tolower}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        60    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         9    0.000    0.000    0.001    0.000 {built-in method builtins.__build_class__}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#   102/100    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       2/1    0.000    0.000    5.271    5.271 {built-in method builtins.exec}
# 1021/1017    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       182    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       181    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.id}
# 4188/4123    0.001    0.000    0.002    0.000 {built-in method builtins.isinstance}
#       270    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 1767/1465    0.000    0.000    0.001    0.000 {built-in method builtins.len}
#        28    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       168    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        93    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         3    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#        23    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open_code}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method marshal.loads}
#         1    0.000    0.000    0.000    0.000 {built-in method now}
#         1    0.000    0.000    0.000    0.000 {built-in method nt._path_splitroot}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.stat}
#        28    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#        13    0.141    0.011    0.141    0.011 {built-in method numpy.array}
#        39    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#       162    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#   159/142    0.064    0.000    0.065    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.datetime_data}
#       109    0.014    0.000    0.014    0.000 {built-in method numpy.empty}
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        10    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#        26    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         2    0.006    0.003    0.006    0.003 {built-in method pandas._libs.missing.isnaobj}
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.reduction.check_result_array}
#        13    0.000    0.000    0.000    0.000 {built-in method pandas._libs.reduction.extract_result}
#         1    0.031    0.031    0.031    0.031 {built-in method pandas._libs.tslib.array_to_datetime}
#         3    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.dtypes.abbrev_to_npy_unit}
#         3    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.offsets.to_offset}
#         3    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.is_utc}
#         7    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.maybe_get_tz}
#         8    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.tz_compare}
#         3    0.000    0.000    0.000    0.000 {function DatetimeLikeArrayMixin.copy at 0x000002CFDF75E830}
#         3    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x000002CFDF8E7370}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         7    0.000    0.000    0.000    0.000 {method '__init_subclass__' of 'object' objects}
#        10    0.000    0.000    0.000    0.000 {method '_from_backing_data' of 'pandas._libs.arrays.NDArrayBacked' objects}
#         3    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#         4    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        63    0.000    0.000    0.000    0.000 {method 'add_index_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#         4    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#         2    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#    118465    0.012    0.000    0.012    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'pandas._libs.internals.BlockPlacement' objects}
#        19    0.009    0.000    0.009    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'as_unit' of 'pandas._libs.tslibs.timedeltas._Timedelta' objects}
#         4    0.000    0.000    0.000    0.000 {method 'as_unit' of 'pandas._libs.tslibs.timestamps._Timestamp' objects}
#         3    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.generic' objects}
#        17    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        11    0.005    0.000    0.005    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        13    0.000    0.000    0.000    0.000 {method 'date' of 'datetime.datetime' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        21    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       104    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#        14    0.000    0.000    0.000    0.000 {method 'findall' of 're.Pattern' objects}
#        12    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       105    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         2    0.000    0.000    0.000    0.000 {method 'has_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#         2    0.000    0.000    0.000    0.000 {method 'increment_above' of 'pandas._libs.internals.BlockPlacement' objects}
#         2    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         7    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#        22    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'is_finite' of 'decimal.Decimal' objects}
#        16    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#        35    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#         7    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        19    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#    117410    0.009    0.000    0.009    0.000 {method 'keys' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         3    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'min' of 'numpy.ndarray' objects}
#        17    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'normalize' of 'pandas._libs.tslibs.timestamps._Timestamp' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'read' of '_io.BufferedReader' objects}
#        26    0.000    0.000    0.000    0.000 {method 'read' of '_io.StringIO' objects}
#        23    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        20    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'repeat' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'reshape' of 'pandas._libs.arrays.NDArrayBacked' objects}
#         4    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        17    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#       180    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#        34    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       379    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        25    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#         8    0.008    0.001    0.008    0.001 {method 'take' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         1    0.002    0.002    0.002    0.002 {method 'unique' of 'pandas._libs.hashtable.PyObjectHashTable' objects}
#         7    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.generic' objects}
#        26    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#    117407    2.747    0.000    2.747    0.000 {orjson.loads}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int64}
#        15    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#        41    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#         1    0.001    0.001    0.001    0.001 {pandas._libs.algos.groupsort_indexer}
#         4    0.001    0.000    0.001    0.000 {pandas._libs.algos.take_2d_axis0_int64_int64}
#         3    0.006    0.002    0.006    0.002 {pandas._libs.algos.take_2d_axis0_object_object}
#         2    0.004    0.002    0.004    0.002 {pandas._libs.algos.take_2d_axis1_int64_int64}
#         3    0.068    0.023    0.068    0.023 {pandas._libs.algos.take_2d_axis1_object_object}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.count_level_2d}
#         1    0.107    0.107    0.107    0.107 {pandas._libs.lib.dicts_to_array}
#         1    0.037    0.037    0.117    0.117 {pandas._libs.lib.fast_unique_multiple_list_gen}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.generate_bins_dt64}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.generate_slices}
#         4    0.003    0.001    0.003    0.001 {pandas._libs.lib.infer_dtype}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#        29    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#        50    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#        64    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#        14    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#       175    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#        59    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#        11    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#         2    0.026    0.013    0.051    0.026 {pandas._libs.lib.map_infer}
#        80    0.178    0.002    0.213    0.003 {pandas._libs.lib.maybe_convert_objects}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_indices_to_slice}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.tslib.first_non_null}
#         3    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.dtypes.is_supported_unit}
#        11    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.np_datetime.py_get_unit_from_dtype}
#         1    0.000    0.000    0.004    0.004 {pandas._libs.tslibs.parsing.guess_datetime_format}
#         1    0.156    0.156    0.156    0.156 {pandas._libs.tslibs.strptime.array_strptime}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.timezones.infer_tzinfo}
#         3    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.timezones.tz_standardize}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.tzconversion.tz_localize_to_utc}
#        14    0.058    0.004    0.058    0.004 {pandas._libs.tslibs.vectorized.ints_to_pydatetime}

# %% [markdown]
# 2. Los top 10 emojis más usados con su respectivo conteo. Debe incluir las siguientes funciones:
# ```python
# def q2_time(file_path: str) -> List[Tuple[str, int]]:
# ```
# ```python
# def q2_memory(file_path: str) -> List[Tuple[str, int]]:
# ```
# ```python
# Returns:
# [("✈️", 6856), ("❤️", 5876), ...]
# ```

# %% [markdown]
# Esta solución optimiza el uso de memoria al utilizar eficientemente la estructura de datos Counter de la biblioteca estándar de Python. En lugar de almacenar todos los emojis y sus frecuencias en estructuras de datos adicionales, se utiliza un objeto Counter para realizar un recuento eficiente de los emojis mientras se recorren los datos. Esto reduce significativamente la cantidad de memoria necesaria, ya que solo se almacenan los emojis y sus conteos, en lugar de los datos completos de los emojis. Además, la función profile se utiliza para realizar la profilización de la memoria y optimizar aún más el uso de recursos durante la ejecución del script.

# %%
result = q2_memory(Path.tweets)
# Out:
# Filename: D:\Johan\repositorios\data_engineer_challenge\src\q2_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     12    160.8 MiB    160.8 MiB           1   @profile
#     13                                         def q2_memory(file_path: str) -> List[Tuple[str, int]]:
#     14                                             """Lee un archivo JSON y devuelve una lista de tuplas con los 10 emojis
#     15                                              más frecuentes y su conteo.
#     16
#     17                                             Args:
#     18                                                 file_path (str): Ruta del archivo JSON que contiene los datos.
#     19
#     20                                             Returns:
#     21                                                 List[Tuple[str, int]]: Lista de tuplas donde cada tupla contiene un
#     22                                                 emoji y su conteo correspondiente.
#     23
#     24                                             """
#     25    188.8 MiB     28.0 MiB           1       data = read_json_file(file_path, transformation='content_list')
#     26
#     27    188.8 MiB      0.0 MiB           1       emojis = Counter()
#     28
#     29    190.6 MiB  -3339.8 MiB      117408       for _, _, content in data:
#     30    190.6 MiB  -3338.0 MiB      117407           emojis.update(count_emoji(content))
#     31
#     32    190.6 MiB      0.0 MiB           1       top_emojis = emojis.most_common(10)
#     33
#     34    190.6 MiB      0.0 MiB           1       return top_emojis

# %%
result
# Out:
# [('🙏', 5049),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('🌾', 2182),
#  ('🇮🇳', 2086),
#  ('🤣', 1668),
#  ('✊', 1651),
#  ('❤️', 1382),
#  ('🙏🏻', 1317),
#  ('💚', 1040)]

# %% [markdown]
# Esta solución optimiza el tiempo de ejecución al aprovechar las capacidades de procesamiento eficiente de la biblioteca pandas. En lugar de utilizar bucles manuales para contar la frecuencia de cada emoji, se utiliza el método explode de pandas para expandir una serie que contiene listas de emojis en una serie donde cada elemento es un emoji individual. Luego, se utiliza el método value_counts para contar la frecuencia de cada emoji de manera eficiente. Esto aprovecha las operaciones vectorizadas de pandas, lo que resulta en un tiempo de ejecución más rápido en comparación con los bucles manuales. Además, esta solución es escalable y puede manejar grandes conjuntos de datos de manera eficiente gracias a la optimización interna de pandas para el procesamiento de datos tabulares.

# %%
cProfile.run('q2_time(Path.tweets)')
# Out:
#          9603855 function calls (9603779 primitive calls) in 8.556 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amax)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(argsort)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_2d)
#         8    0.000    0.000    0.033    0.004 <__array_function__ internals>:177(concatenate)
#        56    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copyto)
#         2    0.000    0.000    0.033    0.016 <__array_function__ internals>:177(vstack)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#   1759998    0.376    0.000    0.629    0.000 <string>:1(<lambda>)
#         1    0.000    0.000    8.556    8.556 <string>:1(<module>)
#        22    0.000    0.000    0.000    0.000 __init__.py:33(using_copy_on_write)
#         5    0.000    0.000    0.000    0.000 _asarray.py:109(<setcomp>)
#         5    0.000    0.000    0.000    0.000 _asarray.py:22(require)
#         8    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         8    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#         8    0.000    0.000    0.000    0.000 _dtype.py:344(_name_get)
#         1    0.000    0.000    0.000    0.000 _mixins.py:266(__getitem__)
#         1    0.000    0.000    0.000    0.000 _mixins.py:83(method)
#         2    0.000    0.000    0.000    0.000 _parser.py:1006(_find_hms_idx)
#         2    0.000    0.000    0.000    0.000 _parser.py:1056(_could_be_tzname)
#         2    0.000    0.000    0.000    0.000 _parser.py:1061(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _parser.py:1099(_parse_min_sec)
#         1    0.000    0.000    0.000    0.000 _parser.py:1133(_parsems)
#         3    0.000    0.000    0.000    0.000 _parser.py:1141(_to_decimal)
#         1    0.000    0.000    0.000    0.000 _parser.py:1177(_build_tzaware)
#         1    0.000    0.000    0.000    0.000 _parser.py:1217(_build_naive)
#         1    0.000    0.000    0.000    0.000 _parser.py:1270(parse)
#         1    0.000    0.000    0.000    0.000 _parser.py:186(__iter__)
#        16    0.000    0.000    0.000    0.000 _parser.py:189(__next__)
#         1    0.000    0.000    0.000    0.000 _parser.py:199(split)
#        16    0.000    0.000    0.000    0.000 _parser.py:203(isword)
#        31    0.000    0.000    0.000    0.000 _parser.py:208(isnum)
#         6    0.000    0.000    0.000    0.000 _parser.py:213(isspace)
#         1    0.000    0.000    0.000    0.000 _parser.py:221(__init__)
#         1    0.000    0.000    0.000    0.000 _parser.py:233(__len__)
#        13    0.000    0.000    0.000    0.000 _parser.py:234(<genexpr>)
#         2    0.000    0.000    0.000    0.000 _parser.py:319(jump)
#         2    0.000    0.000    0.000    0.000 _parser.py:322(weekday)
#         3    0.000    0.000    0.000    0.000 _parser.py:329(month)
#         3    0.000    0.000    0.000    0.000 _parser.py:336(hms)
#         2    0.000    0.000    0.000    0.000 _parser.py:342(ampm)
#         1    0.000    0.000    0.000    0.000 _parser.py:360(convertyear)
#         1    0.000    0.000    0.000    0.000 _parser.py:380(validate)
#         1    0.000    0.000    0.000    0.000 _parser.py:395(__init__)
#         1    0.000    0.000    0.000    0.000 _parser.py:402(has_year)
#         3    0.000    0.000    0.000    0.000 _parser.py:428(append)
#         1    0.000    0.000    0.000    0.000 _parser.py:474(resolve_ymd)
#         1    0.000    0.000    0.000    0.000 _parser.py:482(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 _parser.py:572(parse)
#         1    0.000    0.000    0.000    0.000 _parser.py:62(__init__)
#         1    0.000    0.000    0.000    0.000 _parser.py:666(_parse)
#        16    0.000    0.000    0.000    0.000 _parser.py:77(get_token)
#         2    0.000    0.000    0.000    0.000 _parser.py:875(_parse_numeric_token)
#         2    0.000    0.000    0.000    0.000 _strptime.py:26(_getlang)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:131(geterr)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:32(seterr)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:425(__init__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__enter__)
#         2    0.000    0.000    0.000    0.000 _ufunc_config.py:434(__exit__)
#         8    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 algorithms.py:105(_ensure_data)
#         1    0.000    0.000    0.000    0.000 algorithms.py:183(_reconstruct_data)
#         1    0.000    0.000    0.000    0.000 algorithms.py:216(_ensure_arraylike)
#         1    0.000    0.000    0.001    0.001 algorithms.py:250(_get_hashtable_algo)
#         1    0.000    0.000    0.001    0.001 algorithms.py:268(_check_object_for_strings)
#         1    0.000    0.000    0.003    0.003 algorithms.py:295(unique)
#         1    0.000    0.000    0.003    0.003 algorithms.py:415(unique_with_mask)
#         2    0.000    0.000    0.000    0.000 api.py:367(default_index)
#         2    0.002    0.001    3.283    1.641 apply.py:1010(apply)
#         2    0.000    0.000    0.000    0.000 apply.py:103(__init__)
#         2    0.000    0.000    3.280    1.640 apply.py:1061(apply_standard)
#         2    0.000    0.000    0.000    0.000 apply.py:991(__init__)
#         2    0.000    0.000    0.005    0.003 astype.py:162(astype_array)
#         2    0.000    0.000    0.005    0.003 astype.py:196(astype_array_safe)
#         1    0.000    0.000    0.000    0.000 base.py:2205(is_unique)
#         4    0.000    0.000    0.000    0.000 base.py:286(is_dtype)
#         4    0.000    0.000    0.000    0.000 base.py:326(ndim)
#         1    0.000    0.000    0.000    0.000 base.py:359(size)
#         5    0.000    0.000    0.000    0.000 base.py:3624(get_loc)
#         1    0.000    0.000    0.000    0.000 base.py:450(_engine_type)
#         4    0.000    0.000    0.000    0.000 base.py:46(__len__)
#         2    0.000    0.000    0.046    0.023 base.py:469(__new__)
#         6    0.000    0.000    0.000    0.000 base.py:4936(_values)
#         5    0.000    0.000    0.000    0.000 base.py:494(find)
#         1    0.000    0.000    0.000    0.000 base.py:4962(_get_engine_target)
#         5    0.000    0.000    0.000    0.000 base.py:5108(__contains__)
#         6    0.000    0.000    0.000    0.000 base.py:5158(__getitem__)
#         3    0.000    0.000    0.000    0.000 base.py:54(shape)
#         9    0.000    0.000    0.000    0.000 base.py:56(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:563(empty)
#         2    0.000    0.000    0.000    0.000 base.py:565(_ensure_array)
#         5    0.000    0.000    0.000    0.000 base.py:58(_validate_set_axis)
#         2    0.000    0.000    0.000    0.000 base.py:583(_dtype_to_subclass)
#         5    0.000    0.000    0.000    0.000 base.py:6351(_maybe_cast_indexer)
#         3    0.000    0.000    0.000    0.000 base.py:640(_simple_new)
#        11    0.000    0.000    0.000    0.000 base.py:7069(ensure_index)
#         8    0.000    0.000    0.000    0.000 base.py:7164(maybe_extract_name)
#         2    0.000    0.000    0.000    0.000 base.py:767(__iter__)
#         5    0.000    0.000    0.000    0.000 base.py:809(_reset_identity)
#         1    0.000    0.000    0.000    0.000 base.py:820(_engine)
#         6    0.000    0.000    0.000    0.000 base.py:875(__len__)
#         1    0.000    0.000    0.000    0.000 base.py:931(dtype)
#         2    0.000    0.000    0.000    0.000 blocks.py:1503(delete)
#         5    0.000    0.000    0.000    0.000 blocks.py:164(_consolidate_key)
#        15    0.000    0.000    0.000    0.000 blocks.py:205(mgr_locs)
#         2    0.000    0.000    0.000    0.000 blocks.py:213(make_block)
#        11    0.000    0.000    0.000    0.000 blocks.py:2303(maybe_coerce_values)
#        14    0.000    0.000    0.000    0.000 blocks.py:2332(get_block_type)
#         4    0.000    0.000    0.000    0.000 blocks.py:2370(new_block_2d)
#         5    0.000    0.000    0.000    0.000 blocks.py:2383(new_block)
#         5    0.000    0.000    0.000    0.000 blocks.py:2399(check_ndim)
#         6    0.000    0.000    0.000    0.000 blocks.py:2463(extend_blocks)
#         2    0.000    0.000    0.000    0.000 blocks.py:2479(ensure_block_shape)
#         4    0.000    0.000    0.000    0.000 blocks.py:258(__len__)
#         7    0.000    0.000    0.000    0.000 blocks.py:479(dtype)
#         2    0.000    0.000    0.005    0.003 blocks.py:483(astype)
#         2    0.000    0.000    0.000    0.000 blocks.py:534(copy)
#         4    0.000    0.000    0.000    0.000 blocks.py:888(shape)
#         3    0.000    0.000    0.000    0.000 blocks.py:892(iget)
#        33    0.000    0.000    0.058    0.002 cast.py:1145(maybe_infer_to_datetimelike)
#         1    0.000    0.000    0.000    0.000 cast.py:121(maybe_convert_platform)
#         1    0.000    0.000    0.000    0.000 cast.py:1460(construct_1d_arraylike_from_scalar)
#         1    0.000    0.000    0.000    0.000 cast.py:1521(construct_1d_object_array_from_listlike)
#         2    0.000    0.000    0.000    0.000 common.py:1077(needs_i8_conversion)
#         3    0.000    0.000    0.000    0.000 common.py:1209(is_float_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:1240(<lambda>)
#         3    0.000    0.000    0.000    0.000 common.py:1244(is_bool_dtype)
#        30    0.000    0.000    0.000    0.000 common.py:1322(is_1d_only_ea_dtype)
#         9    0.000    0.000    0.000    0.000 common.py:1335(is_extension_array_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:1389(is_ea_or_datetimelike_dtype)
#         6    0.000    0.000    0.000    0.000 common.py:142(classes)
#         4    0.000    0.000    0.000    0.000 common.py:1435(_is_dtype)
#         6    0.000    0.000    0.000    0.000 common.py:144(<lambda>)
#        15    0.000    0.000    0.000    0.000 common.py:1459(get_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:147(classes_and_not_datetimelike)
#         7    0.000    0.000    0.000    0.000 common.py:1494(_is_dtype_type)
#         6    0.000    0.000    0.000    0.000 common.py:150(cast_scalar_indexer)
#         1    0.000    0.000    0.000    0.000 common.py:152(<lambda>)
#         3    0.000    0.000    0.000    0.000 common.py:158(is_object_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:1631(validate_all_hashable)
#        20    0.000    0.000    0.000    0.000 common.py:1650(<genexpr>)
#         6    0.000    0.000    0.000    0.000 common.py:1656(pandas_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:229(asarray_tuplesafe)
#         2    0.000    0.000    0.000    0.000 common.py:275(is_datetime64_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:296(maybe_iterable_to_list)
#         2    0.000    0.000    0.000    0.000 common.py:309(is_datetime64tz_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:351(is_timedelta64_dtype)
#         5    0.000    0.000    0.000    0.000 common.py:367(apply_if_callable)
#         3    0.000    0.000    0.000    0.000 common.py:386(is_period_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:551(is_dtype_equal)
#        23    0.000    0.000    0.000    0.000 common.py:571(require_length_match)
#         1    0.000    0.000    0.000    0.000 common.py:653(is_integer_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:705(<lambda>)
#         4    0.000    0.000    0.000    0.000 config.py:116(_get_single_key)
#         4    0.000    0.000    0.000    0.000 config.py:134(_get_option)
#         4    0.000    0.000    0.000    0.000 config.py:260(__call__)
#         4    0.000    0.000    0.000    0.000 config.py:578(_select_options)
#         4    0.000    0.000    0.000    0.000 config.py:596(_get_root)
#         8    0.000    0.000    0.000    0.000 config.py:610(_get_deprecated_option)
#         4    0.000    0.000    0.000    0.000 config.py:637(_translate_key)
#         4    0.000    0.000    0.000    0.000 config.py:649(_warn_if_deprecated)
#         1    0.000    0.000    0.165    0.165 construction.py:1001(convert_object_array)
#        21    0.000    0.000    0.165    0.008 construction.py:1023(convert)
#         1    0.000    0.000    0.165    0.165 construction.py:1067(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:197(mgr_to_mgr)
#        30    0.000    0.000    0.000    0.000 construction.py:396(extract_array)
#        11    0.000    0.000    0.000    0.000 construction.py:458(ensure_wrapped_if_datetimelike)
#         1    0.000    0.000    0.405    0.405 construction.py:484(nested_data_to_arrays)
#        26    0.000    0.000    0.053    0.002 construction.py:494(sanitize_array)
#         1    0.000    0.000    0.000    0.000 construction.py:510(treat_as_nested)
#         1    0.000    0.000    0.006    0.006 construction.py:574(_homogenize)
#         1    0.000    0.000    0.000    0.000 construction.py:636(_sanitize_non_ordered)
#        25    0.000    0.000    0.000    0.000 construction.py:644(_sanitize_ndim)
#        23    0.000    0.000    0.000    0.000 construction.py:683(_sanitize_str_dtypes)
#        25    0.000    0.000    0.000    0.000 construction.py:703(_maybe_repeat)
#         1    0.002    0.002    0.405    0.405 construction.py:775(to_arrays)
#         1    0.000    0.000    0.237    0.237 construction.py:886(_list_of_dict_to_arrays)
#    117408    0.070    0.000    0.079    0.000 construction.py:910(<genexpr>)
#         2    0.000    0.000    0.000    0.000 construction.py:911(<genexpr>)
#         1    0.018    0.018    0.018    0.018 construction.py:917(<listcomp>)
#         1    0.000    0.000    0.166    0.166 construction.py:923(_finalize_columns_and_data)
#         1    0.000    0.000    0.000    0.000 construction.py:945(_validate_or_indexify_columns)
#         1    0.027    0.027    0.229    0.229 construction.py:97(arrays_to_mgr)
#     12169    0.009    0.000    3.201    0.000 core.py:283(emoji_list)
#     12169    0.838    0.000    3.192    0.000 core.py:290(<listcomp>)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:1210(is_dataclass)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:1796(__init__)
#         5    0.000    0.000    0.000    0.000 datetimelike.py:1872(freq)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:1941(_creso)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:1945(unit)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2116(ensure_arraylike_for_datetimelike)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2187(validate_inferred_freq)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2224(maybe_infer_freq)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2252(dtype_to_unit)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:307(asi8)
#         1    0.018    0.018    0.233    0.233 datetimelike.py:342(__array__)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:359(__getitem__)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:380(_get_getitem_freq)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:543(copy)
#         1    0.000    0.000    0.001    0.001 datetimes.py:132(_guess_datetime_format_for_array)
#         1    0.000    0.000    0.000    0.000 datetimes.py:155(should_cache)
#         1    0.000    0.000    0.039    0.039 datetimes.py:1986(_sequence_to_dt64ns)
#         1    0.000    0.000    0.035    0.035 datetimes.py:2137(objects_to_datetime64ns)
#         1    0.000    0.000    0.000    0.000 datetimes.py:215(_maybe_cache)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2209(maybe_convert_dtype)
#         3    0.000    0.000    0.000    0.000 datetimes.py:2293(_validate_dt64_dtype)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2347(_validate_tz_from_dtype)
#         1    0.000    0.000    0.000    0.000 datetimes.py:260(_validate_dtype)
#         2    0.000    0.000    0.000    0.000 datetimes.py:268(_simple_new)
#         1    0.000    0.000    0.039    0.039 datetimes.py:293(_from_sequence_not_strict)
#         1    0.000    0.000    0.039    0.039 datetimes.py:306(__new__)
#         1    0.006    0.006    0.288    0.288 datetimes.py:317(_return_parsed_timezone_results)
#         1    0.000    0.000    0.449    0.449 datetimes.py:352(_convert_listlike_datetimes)
#         1    0.004    0.004    0.448    0.448 datetimes.py:473(_array_strptime_with_fallback)
#         2    0.000    0.000    0.000    0.000 datetimes.py:485(<genexpr>)
#        23    0.000    0.000    0.000    0.000 datetimes.py:533(dtype)
#        13    0.000    0.000    0.000    0.000 datetimes.py:558(tz)
#         1    0.000    0.000    0.233    0.233 datetimes.py:600(__array__)
#    117408    0.011    0.000    0.070    0.000 datetimes.py:607(__iter__)
#         1    0.000    0.000    0.450    0.450 datetimes.py:687(to_datetime)
#         1    0.000    0.000    0.000    0.000 datetimes.py:875(tz_localize)
#         2    0.000    0.000    0.000    0.000 datetimes.py:96(tz_to_dtype)
#         2    0.000    0.000    0.000    0.000 dtypes.py:686(__init__)
#         2    0.000    0.000    0.000    0.000 dtypes.py:718(_creso)
#         2    0.000    0.000    0.000    0.000 dtypes.py:725(unit)
#        12    0.000    0.000    0.000    0.000 dtypes.py:732(tz)
#         1    0.000    0.000    0.000    0.000 dtypes.py:801(__eq__)
#         2    0.000    0.000    0.000    0.000 dtypes.py:974(is_dtype)
#         2    0.000    0.000    0.000    0.000 enum.py:801(value)
#     12168    0.003    0.000    0.004    0.000 filters.py:19(<listcomp>)
#     12169    0.010    0.000    3.214    0.000 filters.py:9(count_emoji)
#        11    0.000    0.000    0.000    0.000 flags.py:49(__init__)
#         6    0.000    0.000    0.000    0.000 flags.py:53(allows_duplicate_labels)
#         6    0.000    0.000    0.000    0.000 flags.py:85(allows_duplicate_labels)
#         2    0.000    0.000    0.003    0.001 frame.py:11607(_reindex_for_setitem)
#         2    0.000    0.000    0.000    0.000 frame.py:1489(__len__)
#         3    0.000    0.000    0.000    0.000 frame.py:3639(_ixs)
#         3    0.000    0.000    0.001    0.000 frame.py:3713(__getitem__)
#         2    0.000    0.000    0.003    0.002 frame.py:3931(__setitem__)
#         2    0.000    0.000    0.000    0.000 frame.py:4111(_iset_item_mgr)
#         2    0.000    0.000    0.000    0.000 frame.py:4118(_set_item_mgr)
#         2    0.000    0.000    0.003    0.002 frame.py:4143(_set_item)
#         2    0.000    0.000    0.000    0.000 frame.py:4213(_ensure_valid_index)
#         3    0.000    0.000    0.000    0.000 frame.py:4236(_box_col_values)
#         2    0.000    0.000    0.000    0.000 frame.py:4250(_clear_item_cache)
#         3    0.000    0.000    0.000    0.000 frame.py:4253(_get_item_cache)
#         2    0.000    0.000    0.003    0.001 frame.py:4857(_sanitize_column)
#         1    0.000    0.000    0.634    0.634 frame.py:641(__init__)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1008(_argsort_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1012(argsort)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2672(_amax_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2677(amax)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#        11    0.000    0.000    0.000    0.000 generic.py:265(__init__)
#         6    0.000    0.000    0.000    0.000 generic.py:338(attrs)
#        12    0.000    0.000    0.000    0.000 generic.py:359(flags)
#       173    0.000    0.000    0.000    0.000 generic.py:37(_check)
#         2    0.000    0.000    0.000    0.000 generic.py:4176(_check_setitem_copy)
#       173    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#         1    0.000    0.000    0.000    0.000 generic.py:453(_validate_dtype)
#         6    0.000    0.000    0.000    0.000 generic.py:5931(__finalize__)
#         7    0.000    0.000    0.000    0.000 generic.py:5975(__getattr__)
#         2    0.000    0.000    0.000    0.000 generic.py:599(_info_axis)
#        13    0.000    0.000    0.000    0.000 generic.py:5991(__setattr__)
#         2    0.000    0.000    0.005    0.003 generic.py:6161(astype)
#         5    0.000    0.000    0.000    0.000 generic.py:723(_set_axis)
#         3    0.000    0.000    0.000    0.000 indexing.py:2602(check_dict_or_set_indexers)
#         1    0.000    0.000    0.000    0.000 inference.py:189(is_array_like)
#         5    0.000    0.000    0.000    0.000 inference.py:267(is_dict_like)
#        14    0.000    0.000    0.000    0.000 inference.py:294(<genexpr>)
#         1    0.000    0.000    0.000    0.000 inference.py:300(is_named_tuple)
#        24    0.000    0.000    0.000    0.000 inference.py:328(is_hashable)
#         1    0.000    0.000    0.000    0.000 inference.py:398(is_dataclass)
#         2    0.000    0.000    0.000    0.000 inspect.py:191(isclass)
#         2    0.000    0.000    0.000    0.000 locale.py:396(normalize)
#         2    0.000    0.000    0.000    0.000 locale.py:479(_parse_localename)
#         2    0.000    0.000    0.000    0.000 locale.py:587(getlocale)
#         3    0.000    0.000    0.000    0.000 managers.py:1084(iget)
#         2    0.000    0.000    0.000    0.000 managers.py:1138(iset)
#         2    0.000    0.000    0.000    0.000 managers.py:1195(value_getitem)
#         2    0.000    0.000    0.000    0.000 managers.py:1281(_iset_split_block)
#         7    0.000    0.000    0.000    0.000 managers.py:167(blknos)
#         1    0.000    0.000    0.000    0.000 managers.py:1805(is_consolidated)
#         1    0.000    0.000    0.000    0.000 managers.py:1813(_consolidate_check)
#         1    0.000    0.000    0.000    0.000 managers.py:1819(<listcomp>)
#         1    0.000    0.000    0.092    0.092 managers.py:1823(_consolidate_inplace)
#         5    0.000    0.000    0.000    0.000 managers.py:183(blklocs)
#         2    0.000    0.000    0.000    0.000 managers.py:1838(ndim)
#        10    0.000    0.000    0.000    0.000 managers.py:1847(__init__)
#         4    0.000    0.000    0.000    0.000 managers.py:1860(from_blocks)
#         3    0.000    0.000    0.000    0.000 managers.py:1873(from_array)
#         8    0.000    0.000    0.000    0.000 managers.py:1944(_block)
#         2    0.000    0.000    0.000    0.000 managers.py:2000(dtype)
#         9    0.000    0.000    0.000    0.000 managers.py:2011(internal_values)
#         1    0.000    0.000    0.196    0.196 managers.py:2119(create_block_manager_from_column_arrays)
#        21    0.000    0.000    0.000    0.000 managers.py:2175(_grouping_func)
#         1    0.000    0.000    0.103    0.103 managers.py:2191(_form_blocks)
#         5    0.000    0.000    0.000    0.000 managers.py:223(set_axis)
#         5    0.099    0.020    0.103    0.021 managers.py:2249(_stack_arrays)
#         1    0.000    0.000    0.092    0.092 managers.py:2262(_consolidate)
#        10    0.000    0.000    0.000    0.000 managers.py:2267(<lambda>)
#         2    0.059    0.030    0.092    0.046 managers.py:2279(_merge_blocks)
#         2    0.000    0.000    0.000    0.000 managers.py:2288(<listcomp>)
#         2    0.000    0.000    0.000    0.000 managers.py:2297(<listcomp>)
#         4    0.000    0.000    0.000    0.000 managers.py:233(items)
#         4    0.000    0.000    0.005    0.001 managers.py:306(apply)
#         4    0.000    0.000    0.000    0.000 managers.py:333(<dictcomp>)
#         2    0.000    0.000    0.005    0.003 managers.py:442(astype)
#         2    0.000    0.000    0.000    0.000 managers.py:620(copy)
#         1    0.000    0.000    0.000    0.000 managers.py:982(__init__)
#         1    0.000    0.000    0.000    0.000 missing.py:625(na_value_for_dtype)
#        56    0.000    0.000    0.000    0.000 multiarray.py:1071(copyto)
#         8    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#        56    0.000    0.000    0.001    0.000 numeric.py:289(full)
#         4    0.000    0.000    0.000    0.000 numerictypes.py:282(issubclass_)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:356(issubdtype)
#         1    0.063    0.063    8.556    8.556 q2_time.py:10(q2_time)
#         2    0.000    0.000    0.000    0.000 range.py:166(_simple_new)
#         2    0.000    0.000    0.000    0.000 range.py:485(equals)
#        49    0.000    0.000    0.000    0.000 range.py:892(__len__)
#         2    0.000    0.000    0.000    0.000 re.py:187(match)
#       180    0.000    0.000    0.000    0.000 re.py:197(search)
#         1    0.000    0.000    0.000    0.000 re.py:232(findall)
#         2    0.000    0.000    0.000    0.000 re.py:249(compile)
#       185    0.000    0.000    0.000    0.000 re.py:288(_compile)
#         1    0.754    0.754    5.267    5.267 readers.py:11(read_json_file)
#    117407    0.026    0.000    0.026    0.000 readers.py:51(<lambda>)
#         3    0.000    0.000    0.000    0.000 series.py:1314(_set_as_cached)
#         5    0.000    0.000    0.000    0.000 series.py:1323(_clear_item_cache)
#        10    0.000    0.000    0.001    0.000 series.py:368(__init__)
#         2    0.000    0.000    3.283    1.641 series.py:4516(apply)
#         4    0.000    0.000    0.000    0.000 series.py:574(_constructor)
#         2    0.000    0.000    0.000    0.000 series.py:594(dtype)
#        13    0.000    0.000    0.000    0.000 series.py:621(name)
#        10    0.000    0.000    0.000    0.000 series.py:671(name)
#         9    0.000    0.000    0.000    0.000 series.py:718(_values)
#         4    0.000    0.000    0.000    0.000 series.py:783(__len__)
#         2    0.000    0.000    0.000    0.000 shape_base.py:207(_arrays_for_stack_dispatcher)
#         2    0.000    0.000    0.000    0.000 shape_base.py:218(_vhstack_dispatcher)
#         2    0.000    0.000    0.033    0.016 shape_base.py:222(vstack)
#         2    0.000    0.000    0.000    0.000 shape_base.py:77(_atleast_2d_dispatcher)
#         2    0.000    0.000    0.000    0.000 shape_base.py:81(atleast_2d)
#   1772164    1.401    0.000    2.189    0.000 tokenizer.py:158(tokenize)
#      4582    0.002    0.000    0.002    0.000 tokenizer.py:29(__init__)
#     12169    0.003    0.000    0.003    0.000 tokenizer.py:301(get_search_tree)
#         2    0.000    0.000    0.000    0.000 types.py:176(__get__)
#        35    0.000    0.000    0.000    0.000 typing.py:1737(cast)
#         3    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#        20    0.000    0.000    0.000    0.000 tz.py:77(dst)
#         1    0.000    0.000    0.000    0.000 utils.py:421(check_array_indexer)
#         4    0.000    0.000    0.000    0.000 warnings.py:165(simplefilter)
#         4    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#         4    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#         4    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#         4    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#   1760003    0.253    0.000    0.253    0.000 {built-in method __new__ of type object at 0x00007FFCC069C920}
#         8    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         2    0.000    0.000    0.000    0.000 {built-in method _locale.setlocale}
#         2    0.000    0.000    0.000    0.000 {built-in method _simple_new}
#        12    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    8.556    8.556 {built-in method builtins.exec}
#       265    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        25    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        29    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
# 1761025/1761021    0.166    0.000    0.166    0.000 {built-in method builtins.isinstance}
#        69    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
# 12472/12404    0.002    0.000    0.002    0.000 {built-in method builtins.len}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.815    0.815    0.815    0.815 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method now}
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         7    0.146    0.021    0.146    0.021 {built-in method numpy.array}
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#        58    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#     72/68    0.033    0.000    0.033    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.datetime_data}
#        64    0.004    0.000    0.004    0.000 {built-in method numpy.empty}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         1    0.035    0.035    0.035    0.035 {built-in method pandas._libs.tslib.array_to_datetime}
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.dtypes.abbrev_to_npy_unit}
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.offsets.to_offset}
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.is_utc}
#         4    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.maybe_get_tz}
#         2    0.000    0.000    0.000    0.000 {function DatetimeLikeArrayMixin.copy at 0x000002CFDF75E830}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 {method '_from_backing_data' of 'pandas._libs.arrays.NDArrayBacked' objects}
#         1    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#         3    0.000    0.000    0.000    0.000 {method 'add_index_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#   1877486    0.164    0.000    0.164    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'pandas._libs.internals.BlockPlacement' objects}
#         2    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         5    0.008    0.002    0.008    0.002 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'findall' of 're.Pattern' objects}
#         2    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#      4589    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         2    0.000    0.000    0.000    0.000 {method 'has_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#         4    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'is_finite' of 'decimal.Decimal' objects}
#        16    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#        35    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#    117407    0.009    0.000    0.009    0.000 {method 'keys' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         8    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        26    0.000    0.000    0.000    0.000 {method 'read' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         4    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'pandas._libs.arrays.NDArrayBacked' objects}
#       180    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         4    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.002    0.002    0.002    0.002 {method 'unique' of 'pandas._libs.hashtable.PyObjectHashTable' objects}
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#    117407    2.540    0.000    2.540    0.000 {orjson.loads}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         1    0.104    0.104    0.104    0.104 {pandas._libs.lib.dicts_to_array}
#         1    0.036    0.036    0.115    0.115 {pandas._libs.lib.fast_unique_multiple_list_gen}
#         2    0.005    0.002    0.005    0.002 {pandas._libs.lib.infer_dtype}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         9    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         4    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#        43    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         4    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#         2    0.034    0.017    3.274    1.637 {pandas._libs.lib.map_infer}
#        55    0.177    0.003    0.217    0.004 {pandas._libs.lib.maybe_convert_objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.tslib.first_non_null}
#         3    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.dtypes.is_supported_unit}
#         7    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.np_datetime.py_get_unit_from_dtype}
#         1    0.000    0.000    0.001    0.001 {pandas._libs.tslibs.parsing.guess_datetime_format}
#         1    0.156    0.156    0.156    0.156 {pandas._libs.tslibs.strptime.array_strptime}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.timezones.tz_standardize}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.tzconversion.tz_localize_to_utc}
#        12    0.059    0.005    0.059    0.005 {pandas._libs.tslibs.vectorized.ints_to_pydatetime}
# KeyboardInterrupt

# %% [markdown]
# 3. El top 10 histórico de usuarios (username) más influyentes en función del conteo de las menciones (@) que registra cada uno de ellos. Debe incluir las siguientes funciones:
# ```python
# def q3_time(file_path: str) -> List[Tuple[str, int]]:
# ```
# ```python
# def q3_memory(file_path: str) -> List[Tuple[str, int]]:
# ```
# ```python
# Returns:
# [("LATAM321", 387), ("LATAM_CHI", 129), ...]
# ```

# %% [markdown]
# Esta solución optimiza el uso de memoria al procesar los datos de manera eficiente y almacenar solo la información necesaria para calcular las menciones de usuarios más frecuentes. Utiliza operaciones vectorizadas de pandas para dividir el contenido de los tweets en palabras, luego extrae las menciones de usuario utilizando expresiones regulares y finalmente cuenta la frecuencia de cada mención de usuario. Al utilizar estas operaciones, se evita la necesidad de crear estructuras de datos adicionales para almacenar datos intermedios, lo que reduce significativamente la cantidad de memoria necesaria. Además, la función profile se utiliza para realizar la profilización de la memoria y optimizar aún más el uso de recursos durante la ejecución del script.

# %%
result = q3_memory(Path.tweets)

# %%
result

# %% [markdown]
# Esta solución optimiza el tiempo de ejecución al aprovechar las capacidades de procesamiento eficiente de la biblioteca pandas. En lugar de utilizar bucles manuales para encontrar y contar las menciones de usuarios en cada tweet, se utiliza el método apply de pandas para aplicar la función find_mentions a cada elemento del DataFrame de manera eficiente. Luego, se utiliza el método explode para expandir las listas de menciones de usuarios en una serie donde cada elemento es una mención de usuario individual. Finalmente, se utiliza el método value_counts para contar la frecuencia de cada mención de usuario de manera eficiente y se seleccionan las 10 menciones más frecuentes. Esto aprovecha las operaciones vectorizadas de pandas, lo que resulta en un tiempo de ejecución más rápido en comparación con los bucles manuales. Además, esta solución es escalable y puede manejar grandes conjuntos de datos de manera eficiente gracias a la optimización interna de pandas para el procesamiento de datos tabulares.

# %%
cProfile.run('q3_time(Path.tweets)')
